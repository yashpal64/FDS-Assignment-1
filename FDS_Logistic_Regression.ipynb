# %% [markdown]
# <a href="https://colab.research.google.com/github/yashpal64/Foundations-of-Data-Science/blob/main/FDS_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
z_pred = np.dot(X_test, weights) + bias
y_pred_proba = sigmoid(z_pred)

plt.figure(figsize=(8, 6))
plt.scatter(range(len(y_test)), y_pred_proba, label="Predicted Probabilities", alpha=0.7)
plt.scatter(range(len(y_test)), y_test, label="True Labels", alpha=0.7)
plt.xlabel("Sample Index")
plt.ylabel("Probability / Label")
plt.title("Predicted Probabilities vs. True Labels")
plt.legend()
plt.grid(True)
plt.show()

if X.shape[1] == 2: # Assuming data is 2D for visualization purposes.
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.01),
                         np.arange(x2_min, x2_max, 0.01))

    Z = sigmoid(np.dot(np.c_[xx1.ravel(), xx2.ravel()], weights) + bias)
    Z = Z.reshape(xx1.shape)

    plt.contourf(xx1, xx2, Z, alpha=0.4)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, edgecolors='k')
    plt.title("Decision Boundary")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.show()
else:
    print("Decision boundary plot is only available for 2-dimensional data.")
x_sigmoid = np.linspace(-10, 10, 400)  # Create an array of x values
y_sigmoid = sigmoid(x_sigmoid)

plt.figure(figsize=(8, 6))
plt.plot(x_sigmoid, y_sigmoid)
plt.title("Sigmoid Function")
plt.xlabel("Input (z)")
plt.ylabel("Output (sigmoid(z))")
plt.grid(True)
plt.show()
# Out:
# Decision boundary plot is only available for 2-dimensional data.
